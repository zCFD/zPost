# %%
# read the experimental data --------- this is a trial 

import csv
import pylab as pl
import math 
import numpy as np
from collections 
with open('data.csv' , 'rb') as csvfile:
    data = csv.reader(csvfile, delimiter = ',')
    for row in data:
        print row
# Out:
# ['###', 'PLEASE', 'NOTE:', 'actual', 'alpha=', '7.03938', '', '', '', '', '', '', '', '']
# ['#', 'X,', 'Y,', 'Z', 'are', 'deployed', 'coordinates', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['VARIABLES', '=', 'x/c_local', 'eta', 'z/c_local', 'X', 'Y', 'Z', 'cp_ETW_RUN238', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['Zone', 't="ETW', 'RUN', '238', 'SLAT', 'SECTION', 'INDEX', '1', '(eta', '=', '0.150%)', 'alpha', '=', '7"']
# ['0.9', '0.15', '0.4431', '1.13E+03', '2.14E+02', '-5.50E+01', '-0.874116', '', '', '', '', '', '', '']
# ['0.6', '0.15', '0.4172', '1.12E+03', '2.14E+02', '-6.24E+01', '-1.15604', '', '', '', '', '', '', '']
# ['0.25', '0.15', '0.3341', '1.10E+03', '2.14E+02', '-7.33E+01', '-0.914114', '', '', '', '', '', '', '']
# ['0.1', '0.15', '0.2429', '1.10E+03', '2.14E+02', '-8.04E+01', '-0.474141', '', '', '', '', '', '', '']
# ...
